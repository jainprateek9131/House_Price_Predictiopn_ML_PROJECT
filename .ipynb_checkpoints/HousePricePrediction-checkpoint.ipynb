# %% [markdown]
# # Problem Statement
# (HOUSE PRICE DETECTION - linear regression)

# %% [markdown]
# The data (given below) contains the selling prices of different houses based on different characteristics/attributes like area, no. of rooms, no. of bathrooms, etc.
#
# At times, the property dealers appreciate the prices based on the demand and hence there is rise in prices in real estate. So, in order to cope with this problem
# so that it is beneficial for the customers, we must have a model in place which should tell us the ideal prices of the house based on its characteristics.
#
# The objective of the study is to predict the ideal prices of the houses based on their characteristics using a regression algorithm.
#
# Learned about:
# 1. Data Cleaning
# 2. Implimenting Linear Regression

# %% [markdown]
# # Data Exploration

# %% [markdown]
# 1.Target Variable (Univariate Analysis)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
Raw_Housing_Data = pd.read_csv('1. Regression - Module - (Housing Prices).csv')

# %%
# Data Type Of Target Variable (Sale Price)
Raw_Housing_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        21613 non-null  object
# ...

# %%
# Eyeballing The Vriable
Raw_Housing_Data.head(10)
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
# 5  7237550310         14 May 2017   1230000.0               4
# 6  1321400060        14 June 2017    257500.0               3
# 7  2008000270     15 January 2016    291850.0               3
# 8  2414600126       15 April 2016    229500.0               3
# 9  3793500160       15 March 2016    323000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# ...

# %%
Raw_Housing_Data.tail(10)
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 21603  7852140040      14 August 2017    507250.0               3
# 21604  9834201367     15 January 2016    429000.0               3
# 21605  3448900210     14 October 2017    610685.0               4
# 21606  7936000429       15 March 2016   1010000.0               4
# 21607  2997800021    15 February 2016    475000.0               3
# 21608   263000018         14 May 2017    360000.0               3
# 21609  6600060120    15 February 2016    400000.0               4
# 21610  1523300141        14 June 2017    402101.0               2
# 21611   291310100     15 January 2016    400000.0               3
# 21612  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 21603             2.50               2270.0              5536.0           2.0
# 21604             2.00               1490.0              1126.0           3.0
# ...

# %%
#Descriptive Statistics
Raw_Housing_Data["Sale Price"].describe()
# Out:
# count    2.160900e+04
# mean     5.401984e+05
# std      3.673890e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: Sale Price, dtype: float64

# %%
#Does the target variable contain the outliers that we need to treat..?
plt.scatter(x=Raw_Housing_Data["ID"],y=Raw_Housing_Data["Sale Price"])

# %%
#The seaborn library has the ability to ignore the missing values and create the wishker 
#box plot
import seaborn as sns
sns.boxplot(x=Raw_Housing_Data["Sale Price"])
# Out:
# <AxesSubplot:xlabel='Sale Price'>

# %% [markdown]
# # Different ways to trating outliers:

# %% [markdown]
# 1. Deletion.
# 2. Capping and Imputing.
# 3. Data Transformation.
# 4. Binning

# %%
#Treatment of outliers by imputing
q1 = Raw_Housing_Data["Sale Price"].quantile(0.25)
q3 = Raw_Housing_Data["Sale Price"].quantile(0.75)

# %%
#Inter Quartile Range 
iqr = q3-q1
iqr
# Out:
# 323050.0

# %%
upper_limit = q3 + 1.5*iqr
lower_limit = q1 - 1.5*iqr
upper_limit , lower_limit
# Out:
# (1129575.0, -162625.0)

# %%
def limit_imputer(value):
    if value > upper_limit:
        return upper_limit
    if value < lower_limit:
        return lower_limit
    else:
        return value

# %%
Raw_Housing_Data["Sale Price"] = Raw_Housing_Data["Sale Price"].apply(limit_imputer)

# %%
Raw_Housing_Data["Sale Price"].describe() #outlier treated max
                                          # mean > median so it is left skewed
# Out:
# count    2.160900e+04
# mean     5.116186e+05
# std      2.500620e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      1.129575e+06
# Name: Sale Price, dtype: float64

# %%
# What is the distribution of values of this variable over its range? are the values uniformly or
# normally distributed is data skewd toward lower values (i.e contains more lower values) or 
# towards higher valued ?
# -> identifying and treating missing values
# -> plot histogram for frequency distribution
#  by using deletion
Raw_Housing_Data.dropna(inplace = True , axis = 0 , subset = ['Sale Price'])

# %%
Raw_Housing_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21605 non-null  float64
#  5   Flat Area (in Sqft)                        21600 non-null  float64
#  6   Lot Area (in Sqft)                         21600 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %%
plt.hist(Raw_Housing_Data["Sale Price"], bins = 10 , color = 'green')
plt.xlabel('Intervels')
plt.ylabel('Selling Price')
# Out:
# Text(0, 0.5, 'Selling Price')

# %% [markdown]
# 2. Independent Variables
#        a. Numerical Vriable

# %%
# Treating Outliers in Independent Vriables
# imputation
# Missing Values
Raw_Housing_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21605 non-null  float64
#  5   Flat Area (in Sqft)                        21600 non-null  float64
#  6   Lot Area (in Sqft)                         21600 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %%
numerical_columns = ['No of Bathrooms', 'Flat Area (in Sqft)', 'Lot Area (in Sqft)',
                     'Lot Area (in Sqft)','Area of the House from Basement (in Sqft)',
                     'Latitude','Longitude','Living Area after Renovation (in Sqft)']

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values = np.nan, strategy='median')
Raw_Housing_Data[numerical_columns] = imputer.fit_transform(Raw_Housing_Data[numerical_columns])

# %%
Raw_Housing_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21609 non-null  float64
#  6   Lot Area (in Sqft)                         21609 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %% [markdown]
# # treating missing values for categorical variables
# #imputer = SimpleImputer(missing_values = np.nan, strategy='most_frequent')
# #Raw_Housing_Data['Zipcode'] = imputer.fit_transform(Raw_Housing_Data['Zipcode'])

# %%
Raw_Housing_Data['Zipcode'].shape
# Out:
# (21609,)

# %%
column = Raw_Housing_Data['Zipcode'].values.reshape(-1,1)
column.shape
# Out:
# (21609, 1)

# %%
imputer = SimpleImputer(missing_values = np.nan, strategy='most_frequent')
Raw_Housing_Data['Zipcode'] = imputer.fit_transform(column)

# %%
Raw_Housing_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21609 non-null  float64
#  6   Lot Area (in Sqft)                         21609 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %%
# converting zipcode as categorical variable
Raw_Housing_Data['Zipcode'] = Raw_Housing_Data['Zipcode'].astype(object)

# %%
# Variable Transformation
Raw_Housing_Data['No of Times Visited'].unique()
# Out:
# array(['None', 'Thrice', 'Four', 'Twice', 'Once'], dtype=object)

# %%
mapping = {'None' : "0",
           'Once' : '1',
           'Twice' : '2',
           'Thrice' : '3',
           'Four' : '4'}

Raw_Housing_Data['No of Times Visited'] = Raw_Housing_Data['No of Times Visited'].map(mapping)

# %%
Raw_Housing_Data['No of Times Visited'].unique()
# Out:
# array(['0', '3', '4', '2', '1'], dtype=object)

# %%
Raw_Housing_Data['Ever Renovated'] = np.where(Raw_Housing_Data['Renovated Year'] == 0, 'No', 'Yes')

# %%
Raw_Housing_Data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ...  \
# 0              No                   0  ...
# 1              No                   0  ...
# ...

# %%
Raw_Housing_Data['Purchase Year'] = pd.DatetimeIndex(Raw_Housing_Data['Date House was Sold']).year

# %%
Raw_Housing_Data['Years Since Renovation'] = np.where(Raw_Housing_Data['Ever Renovated'] == 'Yes',
                                                     abs(Raw_Housing_Data['Purchase Year'] - 
                                                        Raw_Housing_Data['Renovated Year']), 0)

# %%
Raw_Housing_Data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Age of House (in Years)  \
# 0              No                   0  ...                      63
# ...

# %%
Raw_Housing_Data.drop(columns = ['Purchase Year', 'Date House was Sold', 'Renovated Year'], inplace = True)

# %%
Raw_Housing_Data.head()
# Out:
#            ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors Waterfront View  \
# 0               1180.0              5650.0           1.0              No
# 1               2570.0              7242.0           2.0              No
# 2                770.0             10000.0           1.0              No
# 3               1960.0              5000.0           1.0              No
# 4               1680.0              8080.0           1.0              No
#
#   No of Times Visited Condition of the House  ...  \
# 0                   0                   Fair  ...
# 1                   0                   Fair  ...
# ...

# %% [markdown]
# b. categorical Variable

# %%
Raw_Housing_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Sale Price                                 21609 non-null  float64
#  2   No of Bedrooms                             21609 non-null  int64
#  3   No of Bathrooms                            21609 non-null  float64
#  4   Flat Area (in Sqft)                        21609 non-null  float64
#  5   Lot Area (in Sqft)                         21609 non-null  float64
#  6   No of Floors                               21609 non-null  float64
#  7   Waterfront View                            21609 non-null  object
#  8   No of Times Visited                        21609 non-null  object
#  9   Condition of the House                     21609 non-null  object
# ...

# %%
#Raw_Housing_Data.drop( columns = 'ID', inplace = True)

# %%
Raw_Housing_Data['Condition of the House'].head(10)
# Out:
# 0         Fair
# 1         Fair
# 2         Fair
# 3    Excellent
# 4         Fair
# 5         Fair
# 6         Fair
# 7         Fair
# 8         Fair
# 9         Fair
# Name: Condition of the House, dtype: object

# %%
Raw_Housing_Data['Condition of the House'].value_counts()
# Out:
# Fair         14028
# Good          5678
# Excellent     1701
# Okay           172
# Bad             30
# Name: Condition of the House, dtype: int64

# %%
Raw_Housing_Data.groupby('Condition of the House',
                                )['Sale Price'].mean().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Condition of the House'>

# %%
Raw_Housing_Data.groupby('Condition of the House',
                                )['Sale Price'].mean().sort_values().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Condition of the House'>

# %%
Raw_Housing_Data.groupby('Waterfront View',
                                )['Sale Price'].mean().sort_values().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Waterfront View'>

# %%
Raw_Housing_Data.groupby('Ever Renovated',
                                )['Sale Price'].mean().sort_values().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Ever Renovated'>

# %%
Raw_Housing_Data.groupby('Zipcode',
                                )['Sale Price'].mean().sort_values().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Zipcode'>

# %% [markdown]
# ANOVA (finds the relationship of independent categorical variable to dependent numerical variable
# 1. NULL HYPOTHESIS : there is no difference in means.
# 2. ALTERNATE HYPOTHESIS
# Two values are obtained in ANOVA:
# 1.F-VALUE = A VERY LARGE
# 2.P-VALUE < 0.5 (THEN WE REJECT THE NULL HYPOTHESIS)

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

# %%
Raw_Housing_Data  = Raw_Housing_Data.rename(columns = {'Sale Price' : 'Sale_Price'})

# %%
Raw_Housing_Data  = Raw_Housing_Data.rename(columns = {'Condition of the House' : 'Condition_of_the_House'})

# %%
Raw_Housing_Data  = Raw_Housing_Data.rename(columns = {'Ever Renovated' : 'Ever_Renovated'})

# %%
Raw_Housing_Data  = Raw_Housing_Data.rename(columns = {'Waterfront View' : 'Waterfront_View'})

# %%
Raw_Housing_Data.head()
# Out:
#            ID  Sale_Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors Waterfront_View  \
# 0               1180.0              5650.0           1.0              No
# 1               2570.0              7242.0           2.0              No
# 2                770.0             10000.0           1.0              No
# 3               1960.0              5000.0           1.0              No
# 4               1680.0              8080.0           1.0              No
#
#   No of Times Visited Condition_of_the_House  ...  \
# 0                   0                   Fair  ...
# 1                   0                   Fair  ...
# ...

# %%
Raw_Housing_Data['Waterfront_View'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
mod = ols('Sale_Price ~ Condition_of_the_House', data  = Raw_Housing_Data).fit()

# %%
Anova_Table = sm.stats.anova_lm( mod, typ = 2)

# %%
print(Anova_Table)
# Out:
#                               sum_sq       df         F        PR(>F)
# Condition_of_the_House  1.441831e+13      4.0  58.25563  5.447605e-49
# Residual                1.336752e+15  21604.0       NaN           NaN

# %%
mod = ols('Sale_Price ~ Waterfront_View', data  = Raw_Housing_Data).fit()
sm.stats.anova_lm( mod, typ = 2)
# Out:
#                        sum_sq       df           F         PR(>F)
# Waterfront_View  3.283737e+13      1.0  538.192683  1.275558e-117
# Residual         1.318333e+15  21607.0         NaN            NaN

# %%
mod = ols('Sale_Price ~ Ever_Renovated', data  = Raw_Housing_Data).fit()
sm.stats.anova_lm( mod, typ = 2)
# Out:
#                       sum_sq       df           F        PR(>F)
# Ever_Renovated  1.998463e+13      1.0  324.378469  5.419055e-72
# Residual        1.331185e+15  21607.0         NaN           NaN

# %%
mod = ols('Sale_Price ~ Zipcode', data  = Raw_Housing_Data).fit()
sm.stats.anova_lm( mod, typ = 2)
# Out:
#                 sum_sq       df           F  PR(>F)
# Zipcode   6.859657e+14     69.0  321.902033     0.0
# Residual  6.652044e+14  21539.0         NaN     NaN

# %% [markdown]
# creation of dummy variable

# %%
Raw_Housing_Data = pd.get_dummies(Raw_Housing_Data,
                                 columns = ['Condition_of_the_House'],
                                 drop_first = True)

# %%
Raw_Housing_Data.head()
# Out:
#            ID  Sale_Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors Waterfront_View  \
# 0               1180.0              5650.0           1.0              No
# 1               2570.0              7242.0           2.0              No
# 2                770.0             10000.0           1.0              No
# 3               1960.0              5000.0           1.0              No
# 4               1680.0              8080.0           1.0              No
#
#   No of Times Visited  Overall Grade  ...  Latitude  Longitude  \
# 0                   0              7  ...   47.5112   -122.257
# ...

# %%
Raw_Housing_Data = pd.get_dummies(Raw_Housing_Data,
                                 columns = ['Waterfront_View','Ever_Renovated'],
                                 drop_first = True)

# %%
Raw_Housing_Data.head()
# Out:
#            ID  Sale_Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors No of Times Visited  \
# 0               1180.0              5650.0           1.0                   0
# 1               2570.0              7242.0           2.0                   0
# 2                770.0             10000.0           1.0                   0
# 3               1960.0              5000.0           1.0                   0
# 4               1680.0              8080.0           1.0                   0
#
#    Overall Grade  Area of the House from Basement (in Sqft)  ...  Longitude  \
# ...

# %% [markdown]
# # Binning

# %% [markdown]
# Binning : if number of levels ofcategorical varible is more than 20 then bin these levels into fewer groups.

# %%
Zip_Table = Raw_Housing_Data.groupby('Zipcode').agg({'Sale_Price' : 'mean'}).sort_values('Sale_Price' , ascending = True)

# %%
Zip_Table.head()
# Out:
#             Sale_Price
# Zipcode
# 98002.0  234284.035176
# 98168.0  240328.371747
# 98032.0  251296.240000
# 98001.0  280804.690608
# 98148.0  284908.596491

# %%
Zip_Table['Zipcode_Group'] = pd.cut(Zip_Table['Sale_Price'] , bins = 10 ,
                                   labels = [ 'Zipcode_Group_0',
                                             'Zipcode_Group_1',
                                             'Zipcode_Group_2',
                                             'Zipcode_Group_3',
                                             'Zipcode_Group_4',
                                            'Zipcode_Group_5',
                                            'Zipcode_Group_6',
                                            'Zipcode_Group_7',
                                             'Zipcode_Group_8',
                                            'Zipcode_Group_9'],
                                    include_lowest = True
                                   )

# %%
Zip_Table = Zip_Table.drop(columns = 'Sale_Price')

# %%
Raw_Housing_Data = pd.merge(Raw_Housing_Data,
                           Zip_Table,
                           left_on='Zipcode',
                           how='left',
                           right_index=True)

# %%
Raw_Housing_Data = Raw_Housing_Data.drop(columns = 'Zipcode')

# %%
Raw_Housing_Data.head()
# Out:
#            ID  Sale_Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors No of Times Visited  \
# 0               1180.0              5650.0           1.0                   0
# 1               2570.0              7242.0           2.0                   0
# 2                770.0             10000.0           1.0                   0
# 3               1960.0              5000.0           1.0                   0
# 4               1680.0              8080.0           1.0                   0
#
#    Overall Grade  Area of the House from Basement (in Sqft)  ...  \
# 0              7                                     1180.0  ...
# ...

# %%
Raw_Housing_Data= pd.get_dummies(Raw_Housing_Data,columns=['Zipcode_Group'],drop_first=True)

# %%
Raw_Housing_Data.head()
# Out:
#            ID  Sale_Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors No of Times Visited  \
# 0               1180.0              5650.0           1.0                   0
# 1               2570.0              7242.0           2.0                   0
# 2                770.0             10000.0           1.0                   0
# 3               1960.0              5000.0           1.0                   0
# 4               1680.0              8080.0           1.0                   0
#
#    Overall Grade  Area of the House from Basement (in Sqft)  ...  \
# 0              7                                     1180.0  ...
# ...

# %%
Raw_Housing_Data.to_csv('Transformed_Housing_Data2.csv',index = False)

# %% [markdown]
# # Linear Regression
# In this implementation, we will be looking at the following the steps as follows:
#
# 1.    Importing Libraries and Dataset
# 2.    Scaling the dataset
# 3.    Checking Multicollinearity and removing it
# 4.    Creating test and training partitions
# 5.    Implementing the Linear Regression model
# 6.    Generating predictions over the test set
# 7.    Evaluating the model
# 8.    Preparing the Residual plot.
# 9.    Checking the Assumptions of Linear Regression.
# 10.   Visualising the Coefficient plot

# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('dark_background')
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Transformed_Housing_Data2.csv')
data.head()
# Out:
#            ID  Sale_Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  No of Times Visited  \
# 0               1180.0              5650.0           1.0                    0
# 1               2570.0              7242.0           2.0                    0
# 2                770.0             10000.0           1.0                    0
# 3               1960.0              5000.0           1.0                    0
# 4               1680.0              8080.0           1.0                    0
#
#    Overall Grade  Area of the House from Basement (in Sqft)  ...  \
# 0              7                                     1180.0  ...
# ...

# %% [markdown]
# # Scaling the dataset

# %% [markdown]
# 1. standardisation
# 2. min max scalling
# 3. normalisation

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
Y = data['Sale_Price']
X = scaler.fit_transform(data.drop(columns = ['Sale_Price']))
X = pd.DataFrame(data = X, columns = data.drop(columns = ['Sale_Price']).columns)
X.head()
# Out:
#          ID  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0  0.885986       -0.398724        -1.447526            -0.979905
# 1  0.637358       -0.398724         0.175684             0.533718
# 2  0.365299       -1.474115        -1.447526            -1.426369
# 3 -0.727767        0.676667         1.149611            -0.130534
# 4 -0.912987       -0.398724        -0.148958            -0.435436
#
#    Lot Area (in Sqft)  No of Floors  No of Times Visited  Overall Grade  \
# 0           -0.228291     -0.915389             -0.30579      -0.563993
# 1           -0.189858      0.936817             -0.30579      -0.563993
# 2           -0.123276     -0.915389             -0.30579      -1.468566
# 3           -0.243983     -0.915389             -0.30579      -0.563993
# 4           -0.169628     -0.915389             -0.30579       0.340581
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# ...

# %% [markdown]
# # Checking and Removing Multicollinearity

# %%
X.corr()
# Out:
#                                                  ID  No of Bedrooms  \
# ID                                         1.000000        0.001450
# No of Bedrooms                             0.001450        1.000000
# No of Bathrooms                            0.005233        0.515813
# Flat Area (in Sqft)                       -0.012379        0.576628
# Lot Area (in Sqft)                        -0.132153        0.031692
# No of Floors                               0.018653        0.175536
# No of Times Visited                        0.011552        0.079575
# Overall Grade                              0.013762        0.349223
# Area of the House from Basement (in Sqft) -0.010724        0.477549
# Basement Area (in Sqft)                   -0.005189        0.303294
# Age of House (in Years)                   -0.021524       -0.154113
# Latitude                                  -0.001983       -0.008708
# Longitude                                  0.020720        0.129569
# ...

# %%
## pair of independent variables with correlation greater than 0.5
k = X.corr()
z = [[str(i),str(j)] for i in k.columns for j in k.columns if (k.loc[i,j] >abs(0.5))&(i!=j)]
z, len(z)
# Out:
# ([['No of Bedrooms', 'No of Bathrooms'],
#   ['No of Bedrooms', 'Flat Area (in Sqft)'],
#   ['No of Bathrooms', 'No of Bedrooms'],
#   ['No of Bathrooms', 'Flat Area (in Sqft)'],
#   ['No of Bathrooms', 'No of Floors'],
#   ['No of Bathrooms', 'Overall Grade'],
#   ['No of Bathrooms', 'Area of the House from Basement (in Sqft)'],
#   ['No of Bathrooms', 'Living Area after Renovation (in Sqft)'],
#   ['Flat Area (in Sqft)', 'No of Bedrooms'],
#   ['Flat Area (in Sqft)', 'No of Bathrooms'],
#   ['Flat Area (in Sqft)', 'Overall Grade'],
#   ['Flat Area (in Sqft)', 'Area of the House from Basement (in Sqft)'],
#   ['Flat Area (in Sqft)', 'Living Area after Renovation (in Sqft)'],
#   ['Lot Area (in Sqft)', 'Lot Area after Renovation (in Sqft)'],
#   ['No of Floors', 'No of Bathrooms'],
#   ['No of Floors', 'Area of the House from Basement (in Sqft)'],
#   ['Overall Grade', 'No of Bathrooms'],
#   ['Overall Grade', 'Flat Area (in Sqft)'],
# ...

# %% [markdown]
# # Calculating VIF

# %%
# Importing Variance_inflation_Factor funtion from the Statsmodels
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif_data = X

## Calculating VIF for every column
VIF = pd.Series([variance_inflation_factor(vif_data.values, i) for i in range(vif_data.shape[1])], index = vif_data.columns)
VIF
# Out:
# ID                                              1.041820
# No of Bedrooms                                  1.639470
# No of Bathrooms                                 3.374993
# Flat Area (in Sqft)                          1481.788910
# Lot Area (in Sqft)                              2.113686
# No of Floors                                    2.127787
# No of Times Visited                             1.433488
# Overall Grade                                   2.968420
# Area of the House from Basement (in Sqft)    1205.625693
# Basement Area (in Sqft)                       345.489923
# Age of House (in Years)                         2.629593
# Latitude                                        2.471731
# Longitude                                       1.675652
# Living Area after Renovation (in Sqft)          3.068170
# Lot Area after Renovation (in Sqft)             2.154157
# Years Since Renovation                          2.788098
# ...

# %%
VIF[VIF == VIF.max()].index[0]
# Out:
# 'Flat Area (in Sqft)'

# %%
def MC_remover(data):
  vif = pd.Series([variance_inflation_factor(data.values, i) for i in range(data.shape[1])], index = data.columns)
  if vif.max() > 5:
    print(vif[vif == vif.max()].index[0],'has been removed')
    data = data.drop(columns = [vif[vif == vif.max()].index[0]])
    return data
  else:
    print('No Multicollinearity present anymore')
    return data

# %%
for i in range(7):
  vif_data = MC_remover(vif_data)

vif_data.head()
# Out:
# Flat Area (in Sqft) has been removed
# Condition_of_the_House_Fair has been removed
# No Multicollinearity present anymore
# No Multicollinearity present anymore
# No Multicollinearity present anymore
# No Multicollinearity present anymore
# No Multicollinearity present anymore
#          ID  No of Bedrooms  No of Bathrooms  Lot Area (in Sqft)  \
# 0  0.885986       -0.398724        -1.447526           -0.228291
# 1  0.637358       -0.398724         0.175684           -0.189858
# 2  0.365299       -1.474115        -1.447526           -0.123276
# 3 -0.727767        0.676667         1.149611           -0.243983
# 4 -0.912987       -0.398724        -0.148958           -0.169628
#
#    No of Floors  No of Times Visited  Overall Grade  \
# 0     -0.915389             -0.30579      -0.563993
# 1      0.936817             -0.30579      -0.563993
# 2     -0.915389             -0.30579      -1.468566
# 3     -0.915389             -0.30579      -0.563993
# ...

# %% [markdown]
# # Remaining Columns

# %%
# Calculating VIF for remaining columns
VIF = pd.Series([variance_inflation_factor(vif_data.values, i) for i in range(vif_data.shape[1])], index = vif_data.columns)
VIF, len(vif_data.columns)
# Out:
# (ID                                           1.041731
#  No of Bedrooms                               1.638990
#  No of Bathrooms                              3.373806
#  Lot Area (in Sqft)                           2.113093
#  No of Floors                                 2.127703
#  No of Times Visited                          1.433467
#  Overall Grade                                2.957909
#  Area of the House from Basement (in Sqft)    4.580370
#  Basement Area (in Sqft)                      1.974981
#  Age of House (in Years)                      2.626561
#  Latitude                                     2.471632
#  Longitude                                    1.675626
#  Living Area after Renovation (in Sqft)       3.063913
#  Lot Area after Renovation (in Sqft)          2.153890
#  Years Since Renovation                       2.788064
#  Condition_of_the_House_Excellent             1.206624
#  Condition_of_the_House_Good                  1.251983
# ...

# %% [markdown]
# # Train/Test set

# %%
X = vif_data
Y = data['Sale_Price']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, random_state = 101)

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((15126, 29), (6483, 29), (15126,), (6483,))

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression(normalize = True)
lr.fit(x_train, y_train)
# Out:
# LinearRegression(normalize=True)

# %%
lr.coef_
# Out:
# array([  -732.72614491,  -3926.23487688,  12024.27839057,  14907.58493057,
#          2702.21094959,  27243.37594311,  59989.05495681,  80678.75316214,
#         27728.58085134,  27883.6985634 ,  21381.21384452, -23812.13883546,
#         17942.98332157,  -2958.71679222, -10169.51452322,  14224.47831714,
#          5077.1980236 ,  -2305.58511287,  10760.40310195,  14576.193708  ,
#         12137.66788157,  33826.69375165,  63256.62839362,  81123.54824905,
#         50660.89518346,  73270.18196499,  40153.12066225,  67389.61328721,
#         22103.06626184])

# %%
predictions = lr.predict(x_test)

# %%
lr.score(x_test, y_test)
# Out:
# 0.8462432261635608

# %% [markdown]
# # 1. Residuals

# %%
residuals = predictions - y_test

residual_table = pd.DataFrame({'residuals':residuals,
                    'predictions':predictions})
residual_table = residual_table.sort_values( by = 'predictions')

# %%
z = [i for i in range(int(residual_table['predictions'].max()))]
k = [0 for i in range(int(residual_table['predictions'].max()))]

# %%
plt.figure(dpi = 130, figsize = (17,7))

plt.scatter( residual_table['predictions'], residual_table['residuals'], color = 'red', s = 2)
plt.plot(z, k, color = 'green', linewidth = 3, label = 'regression line')
plt.ylim(-800000, 800000)
plt.xlabel('fitted points (ordered by predictions)')
plt.ylabel('residuals')
plt.title('residual plot')
plt.legend()
plt.show()

# %% [markdown]
# # 2. Distribution of errors

# %%
plt.figure(dpi = 100, figsize = (10,7))
plt.hist(residual_table['residuals'], color = 'red', bins = 200)
plt.xlabel('residuals')
plt.ylabel('frequency')
plt.title('distribution of residuals')
plt.show()

# %% [markdown]
# # Model Coefficients

# %%
coefficients_table = pd.DataFrame({'column': x_train.columns,
                                  'coefficients': lr.coef_})
coefficient_table = coefficients_table.sort_values(by = 'coefficients')

# %%
plt.figure(figsize=(8, 6), dpi=120)
x = coefficient_table['column']
y = coefficient_table['coefficients']
plt.barh( x, y)
plt.xlabel( "Coefficients")
plt.ylabel('Variables')
plt.title('Normalized Coefficient plot')
plt.show()
